# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array

# %%
model=load_model("vegetable.h5")

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
img=image.load_img(r"/home/wsuser/work/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Tomato___Septoria_leaf_spot/c551c562-b93a-4b2e-9058-12519414b3ff___Matt.S_CG 2882.JPG",target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD4842E0E50>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)

# %%
x
# Out:
# array([[[[156., 143., 153.],
#          [149., 136., 146.],
#          [148., 135., 145.],
#          ...,
#          [149., 133., 144.],
#          [126., 110., 121.],
#          [153., 137., 148.]],
#
#         [[151., 138., 148.],
#          [158., 145., 155.],
#          [149., 136., 146.],
#          ...,
#          [152., 136., 147.],
#          [181., 165., 176.],
#          [182., 166., 177.]],
#
#         [[143., 130., 140.],
#          [160., 147., 157.],
#          [160., 147., 157.],
#          ...,
#          [160., 144., 155.],
#          [163., 147., 158.],
#          [140., 124., 135.]],
#
#         ...,
#
#         [[159., 146., 155.],
#          [162., 149., 158.],
#          [183., 170., 179.],
#          ...,
#          [133., 117., 127.],
#          [130., 114., 124.],
#          [127., 111., 121.]],
#
#         [[147., 134., 143.],
#          [135., 122., 131.],
#          [161., 148., 157.],
#          ...,
#          [153., 137., 147.],
#          [130., 114., 124.],
#          [148., 132., 142.]],
#
#         [[142., 129., 138.],
#          [138., 125., 134.],
#          [166., 153., 162.],
#          ...,
#          [139., 123., 133.],
#          [115.,  99., 109.],
#          [142., 126., 136.]]]], dtype=float32)

# %%
pred=np.argmax(model.predict(x),axis=1)

# %%
pred
# Out:
# array([0])
